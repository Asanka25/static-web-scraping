# %%
import requests
from bs4 import BeautifulSoup
import re
import csv

# %%
# csv_file=open('hirunews.lk.csv','w',newline='',  encoding='utf-8')
# csv_writer=csv.writer(csv_file)
# csv_writer.writerow(['','domain','datestamp','type','content'])
# def switch_demo(month):
#     switcher = {
#          "November":'11',
#         "October":'10',
#          "September":'09'
               
#     }
#     month= switcher.get(month)
#     return month

URL = f'https://www.hirunews.lk/local-news.php?pageID={index}'
#     page = requests.get(URL)
#     soup = BeautifulSoup(page.content, 'lxml')
#     results=soup.find_all('div',class_='column middle')
#     print(len(results))


# def page(index):
#     global count
#     global csv_writer
    
#     URL = f'https://www.hirunews.lk/local-news.php?pageID={index}'
 
#     page = requests.get(URL)
#     soup = BeautifulSoup(page.content, 'lxml')
#     results=soup.find_all('div',class_='column middle')
#     print(len(results))
#     print((URL))
# 
#     post_number=0
#     for model in results:
        
#         link=model.a['href']
#         print(link)
        
#         articleSoup=BeautifulSoup(requests.get(link).content, 'lxml')
        
#         date=model.find('div','middle-tittle-time').text
#         date=date.split()[1:4]
#         m,d,y=switch_demo(date[1]),date[0],date[2]
#         datestamp=[m,d,y]
#         datestamp="/".join(datestamp)
        
#         print(datestamp)
#         try:
#             post=articleSoup.find('div',id='article-phara').text
            
#         except AttributeError:
#             post=''

#         text=" ".join(post.split())

#         print(text,"\n")
#         if text.isspace() or text=="":
#             pass
#         else:
#             count+=1
#             csv_writer.writerow([count,'hirunews.lk',datestamp,'',text])
#             csv_writer.writerow(['','hirunews.lk',datestamp,'',''])




       

#       date=articleSoup.find('div',class_='mndate').text
#         datestamp=f'2020-10-{date}'




# count=0
# for i in range(2,20): #16 210
#     page(i)
# print(count)
# csv_file.close()
# Out:
# 15
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 15
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 11/04/2020
# 15
# 11/04/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 15
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 15
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# 11/03/2020
# ...
